# %%
# %run "../main.ipynb"

# %%
multiple_runs_analysis('../dataset/c201.txt', 'results_analysis', num_runs=100)
# Out:
# Reading dataset -> '../dataset/c201.txt'
# Number of trucks: 25
# Capacity of each truck: 700
# Number of customers: 100
# Run N°1/100
# Reading dataset -> '../dataset/c201.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 15
# Total distance traveled by the trucks: 1880.47
# --------------------------------------------------
# Number of trucks: 25
# Capacity of each truck: 700
# Number of customers: 100
# Running ACO...
# ----------------------------------------------------------------------------------------------------
# Total number of trucks used: 6
# Shortest Path Length: 937.10
# Time taken: 9937.10
# ----------------------------------------------------------------------------------------------------
#
#
# Run N°2/100
# Reading dataset -> '../dataset/c201.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 15
# ...
