# %%
# %run "../main.ipynb"

# %%
multiple_runs_analysis('../dataset/r101.txt', 'results_analysis', num_runs=100)
# Out:
# Reading dataset -> '../dataset/r101.txt'
# Number of trucks: 25
# Capacity of each truck: 200
# Number of customers: 100
# Run N°1/100
# Reading dataset -> '../dataset/r101.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 25
# Total distance traveled by the trucks: 1666.05
# --------------------------------------------------
# Number of trucks: 25
# Capacity of each truck: 200
# Number of customers: 100
# Running ACO...
# ----------------------------------------------------------------------------------------------------
# Total number of trucks used: 25
# Shortest Path Length: 1549.33
# Time taken: 2279.33
# ----------------------------------------------------------------------------------------------------
#
#
# Run N°2/100
# Reading dataset -> '../dataset/r101.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 25
# ...
