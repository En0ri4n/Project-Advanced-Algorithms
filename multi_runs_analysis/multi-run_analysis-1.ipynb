# %%
# %run "../main.ipynb"

# %%
multiple_runs_analysis('../dataset/r201.txt', 'results_analysis', num_runs=100)
# Out:
# Reading dataset -> '../dataset/r201.txt'
# Number of trucks: 25
# Capacity of each truck: 1000
# Number of customers: 100
# Run N°1/100
# Reading dataset -> '../dataset/r201.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 15
# Total distance traveled by the trucks: 1984.96
# --------------------------------------------------
# Number of trucks: 25
# Capacity of each truck: 1000
# Number of customers: 100
# Running ACO...
# ----------------------------------------------------------------------------------------------------
# Total number of trucks used: 12
# Shortest Path Length: 1790.42
# Time taken: 2790.42
# ----------------------------------------------------------------------------------------------------
#
#
# Run N°2/100
# Reading dataset -> '../dataset/r201.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 15
# ...
