# %%
# %run "../main.ipynb"

# %%
multiple_runs_analysis('../dataset/rc201.txt', 'results_analysis', num_runs=100)
# Out:
# Reading dataset -> '../dataset/rc201.txt'
# Number of trucks: 25
# Capacity of each truck: 1000
# Number of customers: 100
# Run N°1/100
# Reading dataset -> '../dataset/rc201.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 15
# Total distance traveled by the trucks: 2468.25
# --------------------------------------------------
# Number of trucks: 25
# Capacity of each truck: 1000
# Number of customers: 100
# Running ACO...
# ----------------------------------------------------------------------------------------------------
# Total number of trucks used: 10
# Shortest Path Length: 2039.12
# Time taken: 3039.12
# ----------------------------------------------------------------------------------------------------
#
#
# Run N°2/100
# Reading dataset -> '../dataset/rc201.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# ...
