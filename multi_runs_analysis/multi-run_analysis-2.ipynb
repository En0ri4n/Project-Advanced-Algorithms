# %%
# %run "../main.ipynb"

# %%
multiple_runs_analysis('../dataset/c101.txt', 'results_analysis', num_runs=100)
# Out:
# Reading dataset -> '../dataset/c101.txt'
# Number of trucks: 25
# Capacity of each truck: 200
# Number of customers: 100
# Run N°1/100
# Reading dataset -> '../dataset/c101.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 21
# Total distance traveled by the trucks: 1870.69
# --------------------------------------------------
# Number of trucks: 25
# Capacity of each truck: 200
# Number of customers: 100
# Running ACO...
# ----------------------------------------------------------------------------------------------------
# Total number of trucks used: 14
# Shortest Path Length: 1187.48
# Time taken: 10187.48
# ----------------------------------------------------------------------------------------------------
#
#
# Run N°2/100
# Reading dataset -> '../dataset/c101.txt'
# --------------------------------------------------
# Nearest Neighbor Solution with Multiple Trucks:
# Number of trucks used: 21
# ...
